# %% [markdown]
# <a href="https://colab.research.google.com/github/joohoshin/Python_Basic/blob/master/11_3_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%9D%BD%EA%B8%B0_%EC%93%B0%EA%B8%B0(Colab).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas 데이터 읽기
# * pandas 에서는 read_csv() 함수를 통해 csv 및 txt 파일 데이터를 손쉽게 읽을 수 있습니다.
# * https://data.seoul.go.kr/dataList/10280/C/2/datasetView.do;jsessionid=F14193A6776D39EE6FAD5343D0DFFD74.new_portal-svr-21

# %% [markdown]
# * 위의 싸이트에서 txt 파일을 받으면 tab으로 데이터가 구분된 파일입니다.
# * 이 파일을 구글 드라이브의 폴더에 업로드하고 불러봅시다

# %%
# 구글 드라이브 연동을 위해 필요
from google.colab import drive
drive.mount('/g') #구글 드라이브를 임의의 명칭으로 지정합니다
# 구글 로그인을 위한 인증코드를 받아서 입력해줍니다
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /g

# %%
# !ls
# Out:
# sample_data

# %%
# !ls '/g'
# Out:
# 'My Drive'

# %%
# !ls '/g/My Drive/Python_202002'
# Out:
# '10-1. 날짜 다루기.ipynb'	        5-1.Function.ipynb
# '10-2. 예외처리.ipynb'		       '5-2. 예제-자판기.ipynb'
# '11-1. 퀴즈 리뷰.ipynb'		       '5-3. 예제_자판기2.ipynb'
# '11-2. Pandas intro.ipynb'	       '6-1. 최대최소값 구하기.ipynb'
# '11-3. 데이터 읽기 쓰기(Colab).ipynb'  '6-2. 예제 곰과나무꾼.ipynb'
# '12-1. Pandas 데이터 확인.ipynb'       '6-3. 예제 메모장.ipynb'
# '12-2. 조건 검색.ipynb'		       '7-1. Set.ipynb'
# '12-3. 연산하기.ipynb'		       '7-2. 예제 - 로또 정답확인.ipynb'
# '2-1. Variables.ipynb'		       '7-3. 예제 로또번호 분석기.ipynb'
# '2-2. Input.ipynb'		       '8-1. 그래프.ipynb'
# '2-3. If.ipynb'			       '8-2. 수학 그래프.ipynb'
# '3-1. while.ipynb'		       '8-3 그래프 활용.ipynb'
# '3-2. for.ipynb'		       '9-1. Numpy 기초.ipynb'
#  3-3.random.ipynb		       '9-2. Numpy 기초 2.ipynb'
#  4-1.List.ipynb			       '9-3 Numpy 활용.ipynb'
#  4-2.Dictionary.ipynb		        grade.csv
# '4-3. 연습.ipynb'		        report.txt

# %% [markdown]
# * 이경우에는 탭으로 데이터가 구분되어 있어 옵션에 sep = '\t'를 넣어주면 됩니다
# * seperator가 탭이라는 뜻입니다
# * 인코딩은 기본적으로 utf8로 읽어옵니다.
# * 윈도우 환경에서 엑셀로 저장한 파일은 보통 cp949 인코딩을 사용합니다.

# %%
import pandas as pd
data = pd.read_csv('/g/My Drive/ML_DL_202002/report.txt', sep = '\t' ) #csv 파일의 경우 기본옵션이므로 sep='\t'가 필요 없습니다

# %%
data
# Out:
#       기간    대분류            분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서    기타
# 0   2019    서울시           서울시  ...      37.3                5.2   1.4
# 1   2019     성별            남자  ...      32.4                4.9   1.1
# 2   2019     성별            여자  ...      41.0                5.4   1.7
# 3   2019    연령별           10대  ...      32.6                3.5     -
# 4   2019    연령별           20대  ...      38.8                6.4   0.1
# 5   2019    연령별           30대  ...      27.3                4.5   0.2
# 6   2019    연령별           40대  ...      35.5                3.3   0.4
# 7   2019    연령별           50대  ...      36.8                5.6   0.8
# 8   2019    연령별        60대 이상  ...      48.7                6.6   5.6
# 9   2019    학력별         중졸 이하  ...      48.6                7.3   8.5
# 10  2019    학력별         고졸 이하  ...      38.6                5.5   0.7
# 11  2019    학력별         대졸 이하  ...      34.0                4.6   0.3
# ...

# %% [markdown]
# * 데이터가 길 때에는 .head(), .tail()등을 사용해서 처음과 마지막 데이터를 확인할 수 있습니다

# %%
data.head(10)
# Out:
#      기간  대분류      분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0  2019  서울시     서울시  ...      37.3                5.2  1.4
# 1  2019   성별      남자  ...      32.4                4.9  1.1
# 2  2019   성별      여자  ...      41.0                5.4  1.7
# 3  2019  연령별     10대  ...      32.6                3.5    -
# 4  2019  연령별     20대  ...      38.8                6.4  0.1
# 5  2019  연령별     30대  ...      27.3                4.5  0.2
# 6  2019  연령별     40대  ...      35.5                3.3  0.4
# 7  2019  연령별     50대  ...      36.8                5.6  0.8
# 8  2019  연령별  60대 이상  ...      48.7                6.6  5.6
# 9  2019  학력별   중졸 이하  ...      48.6                7.3  8.5
#
# [10 rows x 9 columns]

# %%
data.tail(10)
# Out:
#       기간   대분류    분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 42  2019   강서구   강서구  ...      50.5                4.3    1
# 43  2019   구로구   구로구  ...      39.0                2.9  1.3
# 44  2019   금천구   금천구  ...      37.6                2.3  1.7
# 45  2019  영등포구  영등포구  ...      33.9                5.4    -
# 46  2019   동작구   동작구  ...      31.1                7.6    -
# 47  2019   관악구   관악구  ...      34.2                6.1    1
# 48  2019   서초구   서초구  ...      36.6                3.3  1.8
# 49  2019   강남구   강남구  ...      46.4                5.2  1.6
# 50  2019   송파구   송파구  ...      39.4                4.8    1
# 51  2019   강동구   강동구  ...      32.4                8.4  2.3
#
# [10 rows x 9 columns]

# %%
data.tail()
# Out:
#       기간  대분류   분류  ...  운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 47  2019  관악구  관악구  ...      34.2                6.1    1
# 48  2019  서초구  서초구  ...      36.6                3.3  1.8
# 49  2019  강남구  강남구  ...      46.4                5.2  1.6
# 50  2019  송파구  송파구  ...      39.4                4.8    1
# 51  2019  강동구  강동구  ...      32.4                8.4  2.3
#
# [5 rows x 9 columns]
